# %%
# 함수 만들기

def hello():
    print('hello word')

# %%
# 덧셈 함수 만들기
def add(a, b):
    """
    매개변수
    a : int
    b : int

    출력: int
    """
    print(a + b)

add(3, 5)

add.__doc__   # 독스트링을 뭘 썼는 지가 나옴
# Out:
# 8
# '\n매개변수\na : int\nb : int\n\n출력: int\n'
