# %%
# 딕셔너리 만들기
# 딕셔너리 = {}
#     키1: 값1,
#     키2: 값2,
#     키3: 값3,
#     ...
# }
lux = {
    "health": 490,
    "mana": 334,
    "melle":550,
    "armor": 18.72
}

# %%
# 키 이름이 중복되면?
lux = {
    "health": 490,
    "health": 800,
    "mana": 334,
    "melle":550,
    "armor": 18.72
}
