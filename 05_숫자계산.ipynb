# %%
# 나눗셈 후 소수점 이하를 버리는 연산자 ( // )
5 // 2
# Out:
# 2

# %%
# 나눗셈 후 나머디를 구하는 연산자(%)
5 % 2
# Out:
# 1

# %%
# 거듭듭제곱을 구하는 연산자 (**)
2 ** 10
# Out:
# 1024

# %%
# 값을 정수로 만들기
a = 3.3
print(type(int(a)))
b = 10
print(type("b"))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# 괄호 사용하기
35 + (1 * 2)
# Out:
# 38

# %%
# 5.4.Q1
print(10/4)

# 5.5.Q1
print(int(0.2467 * 12 + 4.159))

# 5.6.Q1
print(102 * 0.6 + 225)
# Out:
# 2.5
# 7
# 286.2
