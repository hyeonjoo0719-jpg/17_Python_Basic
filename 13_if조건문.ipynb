# %%
# if 조건문 사용하기
x = 10

if x == 10:
    print("10입니다.")
# Out:
# 10입니다.

# %%
# if 조건문에서 코드를 생략하기
x = 10
if x == 10:
    pass     # 아무것도 안하겠다는 의미, 안적어주면 error가 나옴

# %%
# if 조건문과 들여쓰기
x = 10
if x ==10:
    print('x에 들어가는 숫자는')
print('10입니다.')

print()

x = 5
if x ==10:
    print('x에 들어가는 숫자는')
print('10입니다.')
# Out:
# x에 들어가는 숫자는
# 10입니다.
#
# 10입니다.

# %%
# 중첩 if조건문
x = 15

if x >= 10:
    print('10이상입니다.')

    if x == 15:
        print('15입니다.')

    if x == 20:
        print('20입니다.')
# Out:
# 10이상입니다.
# 15입니다.

# %%
x = int(input())

if x == 10:
    print('10입니다.')

if x == 20:
    print('20입니다.')
# Out:
# 20입니다.

# %%
#13.6.Q1
x = 5
if x != 10:
    print('ok')
# Out:
# ok

# %%
#13.7.Q1
price = int(input())
cupon = input()

if cupon == 'Cash3000':
    balance = price - 3000

if cupon == 'Cash5000':
    balance = price - 5000
    
print(balance)
# Out:
# 67000
